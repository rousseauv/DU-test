# %% [markdown]
# # Data exploration

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Summary

# %% [markdown]
# ### Load training dataset as a dataframe

# %%
df = pd.read_csv('ds-tech-interview/train_auto.csv')

# %% [markdown]
# ### Visualize dataframe informations

# %%
df.head()
# Out:
#    INDEX  TARGET_FLAG  TARGET_AMT  KIDSDRIV   AGE  HOMEKIDS   YOJ    INCOME  \
# 0      1            0         0.0         0  60.0         0  11.0   $67,349
# 1      2            0         0.0         0  43.0         0  11.0   $91,449
# 2      4            0         0.0         0  35.0         1  10.0   $16,039
# 3      5            0         0.0         0  51.0         0  14.0       NaN
# 4      6            0         0.0         0  50.0         0   NaN  $114,986
#
#   PARENT1  HOME_VAL  ... BLUEBOOK TIF CAR_TYPE RED_CAR  OLDCLAIM CLM_FREQ  \
# 0      No        $0  ...  $14,230  11  Minivan     yes    $4,461        2
# 1      No  $257,252  ...  $14,940   1  Minivan     yes        $0        0
# 2      No  $124,191  ...   $4,010   4    z_SUV      no   $38,690        2
# 3      No  $306,251  ...  $15,440   7  Minivan     yes        $0        0
# 4      No  $243,925  ...  $18,000   1    z_SUV      no   $19,217        2
#
#   REVOKED  MVR_PTS CAR_AGE           URBANICITY
# ...

# %%
df.columns
# Out:
# Index(['INDEX', 'TARGET_FLAG', 'TARGET_AMT', 'KIDSDRIV', 'AGE', 'HOMEKIDS',
#        'YOJ', 'INCOME', 'PARENT1', 'HOME_VAL', 'MSTATUS', 'SEX', 'EDUCATION',
#        'JOB', 'TRAVTIME', 'CAR_USE', 'BLUEBOOK', 'TIF', 'CAR_TYPE', 'RED_CAR',
#        'OLDCLAIM', 'CLM_FREQ', 'REVOKED', 'MVR_PTS', 'CAR_AGE', 'URBANICITY'],
#       dtype='object')

# %%
df["OLDCLAIM"].value_counts()
# Out:
# $0         5009
# $1,391        4
# $4,263        4
# $1,310        4
# $3,338        3
#            ...
# $44,429       1
# $33,611       1
# $6,880        1
# $975          1
# $9,543        1
# Name: OLDCLAIM, Length: 2857, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8161, step=1)

# %%
df.dtypes
# Out:
# INDEX            int64
# TARGET_FLAG      int64
# TARGET_AMT     float64
# KIDSDRIV         int64
# AGE            float64
# HOMEKIDS         int64
# YOJ            float64
# INCOME          object
# PARENT1         object
# HOME_VAL        object
# MSTATUS         object
# SEX             object
# EDUCATION       object
# JOB             object
# TRAVTIME         int64
# CAR_USE         object
# BLUEBOOK        object
# TIF              int64
# CAR_TYPE        object
# RED_CAR         object
# OLDCLAIM        object
# CLM_FREQ         int64
# REVOKED         object
# MVR_PTS          int64
# CAR_AGE        float64
# URBANICITY      object
# dtype: object

# %% [markdown]
# ### Visualize integer and float distributions informations of the dataframe

# %%
df.describe()
# Out:
#               INDEX  TARGET_FLAG     TARGET_AMT     KIDSDRIV          AGE  \
# count   8161.000000  8161.000000    8161.000000  8161.000000  8155.000000
# mean    5151.867663     0.263816    1504.324648     0.171057    44.790313
# std     2978.893962     0.440728    4704.026930     0.511534     8.627589
# min        1.000000     0.000000       0.000000     0.000000    16.000000
# 25%     2559.000000     0.000000       0.000000     0.000000    39.000000
# 50%     5133.000000     0.000000       0.000000     0.000000    45.000000
# 75%     7745.000000     1.000000    1036.000000     0.000000    51.000000
# max    10302.000000     1.000000  107586.136160     4.000000    81.000000
#
#           HOMEKIDS          YOJ     TRAVTIME          TIF     CLM_FREQ  \
# count  8161.000000  7707.000000  8161.000000  8161.000000  8161.000000
# mean      0.721235    10.499286    33.485725     5.351305     0.798554
# std       1.116323     4.092474    15.908333     4.146635     1.158453
# ...

# %% [markdown]
# ### Visualize objects informations of the dataframe (excepting those with dollars)

# %%
df["PARENT1"].value_counts()
# Out:
# No     7084
# Yes    1077
# Name: PARENT1, dtype: int64

# %%
df["MSTATUS"].value_counts()
# Out:
# Yes     4894
# z_No    3267
# Name: MSTATUS, dtype: int64

# %%
df["SEX"].value_counts()
# Out:
# z_F    4375
# M      3786
# Name: SEX, dtype: int64

# %%
df["EDUCATION"].value_counts()
# Out:
# z_High School    2330
# Bachelors        2242
# Masters          1658
# <High School     1203
# PhD               728
# Name: EDUCATION, dtype: int64

# %%
df["JOB"].value_counts()
# Out:
# z_Blue Collar    1825
# Clerical         1271
# Professional     1117
# Manager           988
# Lawyer            835
# Student           712
# Home Maker        641
# Doctor            246
# Name: JOB, dtype: int64

# %%
df["CAR_USE"].value_counts()
# Out:
# Private       5132
# Commercial    3029
# Name: CAR_USE, dtype: int64

# %%
df["CAR_TYPE"].value_counts()
# Out:
# z_SUV          2294
# Minivan        2145
# Pickup         1389
# Sports Car      907
# Van             750
# Panel Truck     676
# Name: CAR_TYPE, dtype: int64

# %%
df["RED_CAR"].value_counts()
# Out:
# no     5783
# yes    2378
# Name: RED_CAR, dtype: int64

# %%
df["REVOKED"].value_counts()
# Out:
# No     7161
# Yes    1000
# Name: REVOKED, dtype: int64

# %%
df["URBANICITY"].value_counts()
# Out:
# Highly Urban/ Urban      6492
# z_Highly Rural/ Rural    1669
# Name: URBANICITY, dtype: int64

# %% [markdown]
# ### Visualize objects informations of the dataframe (just those with dollars)

# %%
df["INCOME"].value_counts()
# Out:
# $0          615
# $61,790       4
# $26,840       4
# $48,509       4
# $82,398       3
#            ...
# $58,839       1
# $118,786      1
# $78,348       1
# $123,358      1
# $23,097       1
# Name: INCOME, Length: 6612, dtype: int64

# %%
df["HOME_VAL"].value_counts()
# Out:
# $0          2294
# $111,129       3
# $332,673       3
# $319,400       3
# $173,130       3
#             ...
# $321,483       1
# $248,221       1
# $221,350       1
# $99,253        1
# $388,141       1
# Name: HOME_VAL, Length: 5106, dtype: int64

# %%
df["BLUEBOOK"].value_counts()
# Out:
# $1,500     157
# $6,000      34
# $5,800      33
# $6,200      33
# $6,400      31
#           ...
# $26,580      1
# $23,650      1
# $3,830       1
# $33,400      1
# $10,050      1
# Name: BLUEBOOK, Length: 2789, dtype: int64

# %%
df["OLDCLAIM"].value_counts()
# Out:
# $0         5009
# $1,391        4
# $4,263        4
# $1,310        4
# $3,338        3
#            ...
# $44,429       1
# $33,611       1
# $6,880        1
# $975          1
# $9,543        1
# Name: OLDCLAIM, Length: 2857, dtype: int64

# %% [markdown]
# ### Redefine all these object with dollars replacing , with . and without dollars

# %%
df['INCOME'] = df.INCOME.str.replace('$', '')
df['INCOME'] = df.INCOME.str.replace(',', '.').astype(float)
# Out:
# <ipython-input-23-b5f000005e3e>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['INCOME'] = df.INCOME.str.replace('$', '')

# %%
df['HOME_VAL'] = df.HOME_VAL.str.replace('$', '')
df['HOME_VAL'] = df.HOME_VAL.str.replace(',', '.').astype(float)
# Out:
# <ipython-input-24-06b67c64e56c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['HOME_VAL'] = df.HOME_VAL.str.replace('$', '')

# %%
df['BLUEBOOK'] = df.BLUEBOOK.str.replace('$', '')
df['BLUEBOOK'] = df.BLUEBOOK.str.replace(',', '.').astype(float)
# Out:
# <ipython-input-25-a783a8b1c135>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['BLUEBOOK'] = df.BLUEBOOK.str.replace('$', '')

# %%
df['OLDCLAIM'] = df.OLDCLAIM.str.replace('$', '')
df['OLDCLAIM'] = df.OLDCLAIM.str.replace(',', '.').astype(float)
# Out:
# <ipython-input-26-10a1d86a054a>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['OLDCLAIM'] = df.OLDCLAIM.str.replace('$', '')

# %% [markdown]
# ### Visualize and count missing values per column

# %%
plt.rcParams['figure.figsize'] = [15, 10]
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum(axis = 0)
# Out:
# INDEX            0
# TARGET_FLAG      0
# TARGET_AMT       0
# KIDSDRIV         0
# AGE              6
# HOMEKIDS         0
# YOJ            454
# INCOME         445
# PARENT1          0
# HOME_VAL       464
# MSTATUS          0
# SEX              0
# EDUCATION        0
# JOB            526
# TRAVTIME         0
# CAR_USE          0
# BLUEBOOK         0
# TIF              0
# CAR_TYPE         0
# RED_CAR          0
# OLDCLAIM         0
# CLM_FREQ         0
# REVOKED          0
# MVR_PTS          0
# CAR_AGE        510
# URBANICITY       0
# dtype: int64

# %% [markdown]
# ## Analysis of predictor variables

# %% [markdown]
# ### Separate num(erical) parameters and cat(egorical) parameters

# %%
PARAM = ['TARGET_FLAG', 'TARGET_AMT', 'KIDSDRIV', 'AGE', 'HOMEKIDS',
       'YOJ', 'INCOME', 'PARENT1', 'HOME_VAL', 'MSTATUS', 'SEX', 'EDUCATION',
       'JOB', 'TRAVTIME', 'CAR_USE', 'BLUEBOOK', 'TIF', 'CAR_TYPE', 'RED_CAR',
       'OLDCLAIM', 'CLM_FREQ', 'REVOKED', 'MVR_PTS', 'CAR_AGE', 'URBANICITY']
PARAM_NUM = ['TARGET_AMT', 'KIDSDRIV', 'AGE', 'HOMEKIDS',
       'YOJ', 'INCOME', 'HOME_VAL', 'TRAVTIME', 'BLUEBOOK', 'TIF',
       'OLDCLAIM', 'CLM_FREQ', 'MVR_PTS', 'CAR_AGE']
PARAM_CAT = ['PARENT1', 'MSTATUS', 'SEX', 'EDUCATION',
       'JOB', 'CAR_USE', 'CAR_TYPE', 'RED_CAR', 'REVOKED', 'URBANICITY']

# %% [markdown]
# ### Boxplot for numeric variables

# %%
fig1, axes1 = plt.subplots(2,7)

for var, ax in zip(PARAM_NUM, axes1.flatten()):
    sns.boxenplot(y=var, x="TARGET_FLAG", data=df, ax=ax)
    
plt.tight_layout()

# %% [markdown]
# ### Barplot for categorical variables

# %%
fig2, axes2 = plt.subplots(2, 5)
for var, ax in zip(PARAM_CAT, axes2.flatten()):
    sns.barplot(x=var, y="TARGET_FLAG", data=df, ax=ax)
    for label in ax.get_xticklabels():
        label.set_rotation(90)
plt.tight_layout()

# %% [markdown]
# ### Plot histograms for numeric variables

# %%
df[PARAM].hist(bins=15, figsize=(15, 15), layout=(5, 5));

# %% [markdown]
# ### Calculate and plot correlation matrix

# %%
corrMatrix = df[PARAM_NUM].corr()

# %%
sns.heatmap(corrMatrix, annot=True, cmap="PiYG", center=0)
plt.figure()
plt.show()
